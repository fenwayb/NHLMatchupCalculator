# %%
import pandas as pd

# %%
s_21_df = pd.read_csv("resources/skaters/2021-2020.csv")
s_21_df
# Out:
#       Unnamed: 0                   player                team  gp   g   a  \
# 0              0       Connor McDavid (C)     Edmonton Oilers  80  44  79
# 1              1     Johnny Gaudreau (LW)      Calgary Flames  82  40  75
# 2              2  Jonathan Huberdeau (LW)    Florida Panthers  80  30  85
# 3              3     Leon Draisaitl (C/W)     Edmonton Oilers  80  55  55
# 4              4     Kirill Kaprizov (LW)      Minnesota Wild  81  47  61
# ...          ...                      ...                 ...  ..  ..  ..
# 1015        1015    Victor Söderström (D)     Arizona Coyotes  16   0   0
# 1016        1016     Austin Poganski (RW)       Winnipeg Jets  16   0   0
# 1017        1017     Mikhail Maltsev (LW)  Colorado Avalanche  18   0   0
# 1018        1018         Olli Juolevi (D)              totals  18   0   0
# 1019        1019    Mason Geertsen (LW/D)   New Jersey Devils  25   0   0
#
#        tp   ppg  pim  +/-                                               link  \
# ...

# %%
g_21_df = pd.read_csv('Resources/goalies/g_2021-2020.csv')
g_21_df
# Out:
#      Unnamed: 0             player                 team  gp   gaa    sv%   w  \
# 0             0   Igor Shestyorkin     New York Rangers  53  2.07  0.935  36
# 1             1       Ilya Sorokin   New York Islanders  52  2.40  0.925  26
# 2             2  Frederik Andersen  Carolina Hurricanes  52  2.17  0.922  35
# 3             3    Jacob Markström       Calgary Flames  63  2.22  0.922  37
# 4             4      Darcy Kuemper   Colorado Avalanche  57  2.54  0.921  37
# ..          ...                ...                  ...  ..   ...    ...  ..
# 114         114    Jack LaFontaine  Carolina Hurricanes   2  7.20  0.780   0
# 115         115      Carter Hutton      Arizona Coyotes   3  7.76  0.741   0
# 116         116      Hugo Alnefelt  Tampa Bay Lightning   1  9.00  0.700   0
# 117         117         Tom Hodges        Anaheim Ducks   1  3.11  0.667   0
# 118         118    Michael McNiven   Montréal Canadiens   1  9.00  0.571   0
#
#       l  t  so   toi   svs   ga  \
# ...

# %%
mid_df = s_22_df[['player', 'team', 'gp', 'g', 'a', 'tp', 'ppg', 'pim', '+/-', 'season', 'playername', 'position']]
mid_df
# Out:
#                    player                  team gp  g  a  tp   ppg pim +/-  \
# 0     Artemi Panarin (LW)      New York Rangers  4  2  8  10  2.50   2  -1
# 1      Mika Zibanejad (C)      New York Rangers  4  4  4   8  2.00   0   2
# 2     David Pastrnak (RW)         Boston Bruins  4  3  5   8  2.00   4   1
# 3    Steven Stamkos (C/W)   Tampa Bay Lightning  4  6  1   7  1.75   6   1
# 4     Gabriel Vilardi (C)     Los Angeles Kings  5  4  3   7  1.40   2   3
# ..                    ...                   ... .. .. ..  ..   ...  ..  ..
# 721     Dylan Samberg (D)         Winnipeg Jets  -  -  -   -     -   -   -
# 722      Ian Mitchell (D)    Chicago Blackhawks  -  -  -   -     -   -   -
# 723     Nolan Patrick (C)  Vegas Golden Knights  -  -  -   -     -   -   -
# 724       Cale Fleury (D)        Seattle Kraken  -  -  -   -     -   -   -
# 725        Ethan Bear (D)   Carolina Hurricanes  -  -  -   -     -   -   -
#
#         season        playername position
# ...

# %%
dflist=[]
years = ['2022-2021', '2021-2020', '2020-2019','2019-2018','2018-2017','2017-2016','2016-2015','2015-2014','2014-2013']
for x in years:
    df = pd.read_csv(f'Resources/skaters/{x}.csv')
    dflist.append(df)

# %%
dflist
# Out:
# [     Unnamed: 0                player                  team gp  g  a  tp  \
#  0             0   Artemi Panarin (LW)      New York Rangers  4  2  8  10
#  1             1    Mika Zibanejad (C)      New York Rangers  4  4  4   8
#  2             2   David Pastrnak (RW)         Boston Bruins  4  3  5   8
#  3             3  Steven Stamkos (C/W)   Tampa Bay Lightning  4  6  1   7
#  4             4   Gabriel Vilardi (C)     Los Angeles Kings  5  4  3   7
#  ..          ...                   ...                   ... .. .. ..  ..
#  721         721     Dylan Samberg (D)         Winnipeg Jets  -  -  -   -
#  722         722      Ian Mitchell (D)    Chicago Blackhawks  -  -  -   -
#  723         723     Nolan Patrick (C)  Vegas Golden Knights  -  -  -   -
#  724         724       Cale Fleury (D)        Seattle Kraken  -  -  -   -
#  725         725        Ethan Bear (D)   Carolina Hurricanes  -  -  -   -
#
#        ppg pim +/-                                               link  \
# ...
