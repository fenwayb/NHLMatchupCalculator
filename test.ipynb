# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# #importing each table as a df to check dtypes
# game_plays_df = pd.read_csv('Resources/data/game_plays.csv')
# game_df = pd.read_csv('Resources/data/game.csv')
# game_plays_players_df = pd.read_csv('Resources/data/game_plays_players.csv')
# game_teams_stats_df = pd.read_csv('Resources/data/game_teams_stats.csv')
# game_shifts_df = pd.read_csv('Resources/data/game_shifts.csv')
# player_info_df = pd.read_csv('Resources/data/player_info.csv')
# game_skater_stats_df = pd.read_csv('Resources/data/game_skater_stats.csv')
# game_goalie_stats_df = pd.read_csv('Resources/data/game_goalie_stats.csv')
# team_info_df = pd.read_csv('Resources/data/team_info.csv')
# game_officials_df = pd.read_csv('Resources/data/game_officials.csv')
# game_goals_df = pd.read_csv('Resources/data/game_goals.csv')
# game_penalties_df = pd.read_csv('Resources/data/game_penalties.csv')
# game_scratches_df = pd.read_csv('Resources/data/game_scratches.csv')

# %%
# game_plays_df.dtypes
# game_df.dtypes
# game_plays_players_df.dtypes
# game_teams_stats_df.dtypes
# game_shifts_df.dtypes
# player_info_df.dtypes
# game_skater_stats_df.dtypes
# game_goalie_stats_df.dtypes
# team_info_df.dtypes
# game_officials_df.dtypes
# game_goals_df.dtypes
# game_penalties_df.dtypes
# game_scratches_df.dtypes

# %%
game_teams_stats_df = pd.read_csv('Resources/game_teams_stats.csv')
team_df = pd.read_csv('Resources/team_info.csv')

# %%
game_teams_stats_df
# Out:
#           game_id  team_id   HoA    won settled_in        head_coach  goals  \
# 0      2016020045        4  away  False        REG      Dave Hakstol    4.0
# 1      2016020045       16  home   True        REG  Joel Quenneville    7.0
# 2      2017020812       24  away   True         OT     Randy Carlyle    4.0
# 3      2017020812        7  home  False         OT      Phil Housley    3.0
# 4      2015020314       21  away   True        REG       Patrick Roy    4.0
# ...           ...      ...   ...    ...        ...               ...    ...
# 52605  2018030416       19  home  False        REG      Craig Berube    1.0
# 52606  2018030417       19  away   True        REG      Craig Berube    4.0
# 52607  2018030417        6  home  False        REG     Bruce Cassidy    1.0
# 52608  2018030417       19  away   True        REG      Craig Berube    4.0
# 52609  2018030417        6  home  False        REG     Bruce Cassidy    1.0
#
# ...

# %%
# game_teams_stats_df[game_teams_stats_df['shots'] <= 10]

# %%
# team_df

# %%
ml_table = pd.read_csv('Resources/ml_table.csv', index_col=1)
ml_table
# Out:
#                  game_id abbreviation_home won_home  goals_home  \
# team_id_home
# 7             2000020003               BUF        t           4
# 4             2000020004               PHI        t           6
# 20            2000020005               CGY        f           3
# 27            2000020006               PHX        t           4
# 1             2000020007               NJD        t           8
# ...                  ...               ...      ...         ...
# 14            2019030412               TBL        t           3
# 25            2019030413               DAL        f           2
# 25            2019030414               DAL        f           4
# 14            2019030415               TBL        f           2
# 25            2019030416               DAL        f           0
#
#               powerPlayPrct_home  penaltyKillPrct_home  shots_home  \
# team_id_home
# 7                       0.000000              0.857143          30
# ...

# %%
x= "powerPlayPrct_home"
ml_table = ml_table.sort_values(by=[f"{x}"], ascending=True)
plt.plot(range(len(ml_table)), ml_table[f"{x}"])

# %%
ml_table[f"{x}"].describe()
# Out:
# count    22514.000000
# mean         0.186865
# std          0.224687
# min          0.000000
# 25%          0.000000
# 50%          0.142857
# 75%          0.333333
# max          1.000000
# Name: powerPlayPrct_home, dtype: float64
